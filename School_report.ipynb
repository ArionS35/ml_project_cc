# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Dataset.csv")
df
# Out:
#     school sex address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F       U     GT3       A     4   4.0   at_home   teacher
# 1       GP   F       U     GT3       T     1   1.0   at_home     other
# 2       GP   F       U     LE3       T     1   1.0   at_home     other
# 3       GP   F       U     GT3       T     4   2.0    health  services
# 4       GP   F       U     GT3       T     3   3.0     other     other
# ..     ...  ..     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F       R     GT3       T     2   3.0  services     other
# 645     MS   F       U     LE3       T     3   1.0   teacher  services
# 646     MS   F       U     GT3       T     1   1.0     other     other
# 647     MS   M       U     LE3       T     3   1.0  services  services
# 648     MS   M       R     LE3       T     3   2.0  services     other
#
#      reason  ... Dalc  health  absences  G1    G2  G3 Feature_1 Feature_2  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   address     649 non-null    object
#  3   famsize     599 non-null    object
#  4   Pstatus     649 non-null    object
#  5   Medu        649 non-null    int64
#  6   Fedu        576 non-null    float64
#  7   Mjob        649 non-null    object
#  8   Fjob        649 non-null    object
#  9   reason      649 non-null    object
#  10  guardian    649 non-null    object
#  11  traveltime  576 non-null    float64
#  12  failures    649 non-null    int64
#  13  schoolsup   649 non-null    object
#  14  famsup      649 non-null    object
#  15  paid        649 non-null    object
#  16  activities  649 non-null    object
#  17  nursery     649 non-null    object
#  18  higher      573 non-null    object
# ...

# %%
df['Feature_1'].max()
# Out:
# np.float64(22.0)

# %%
df['Feature_1'].min()
# Out:
# np.float64(15.0)

# %%
df['Feature_2'].max()
# Out:
# np.float64(4.0)

# %%
df['Feature_2'].min()
# Out:
# np.float64(1.0)

# %%
df['Feature_3'].max()
# Out:
# np.float64(5.0)

# %%
df['Feature_3'].min()
# Out:
# np.float64(1.0)

# %%
df['address'] = df['address'].map({'U':1,'R':0})
df
# Out:
#     school sex  address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F        1     GT3       A     4   4.0   at_home   teacher
# 1       GP   F        1     GT3       T     1   1.0   at_home     other
# 2       GP   F        1     LE3       T     1   1.0   at_home     other
# 3       GP   F        1     GT3       T     4   2.0    health  services
# 4       GP   F        1     GT3       T     3   3.0     other     other
# ..     ...  ..      ...     ...     ...   ...   ...       ...       ...
# 644     MS   F        0     GT3       T     2   3.0  services     other
# 645     MS   F        1     LE3       T     3   1.0   teacher  services
# 646     MS   F        1     GT3       T     1   1.0     other     other
# 647     MS   M        1     LE3       T     3   1.0  services  services
# 648     MS   M        0     LE3       T     3   2.0  services     other
#
#      reason  ... Dalc  health  absences  G1    G2  G3 Feature_1 Feature_2  \
# ...

# %%
df['sex'] = df['sex'].map({'M':1,'F':0})

# %%
df['famsize'] = df['famsize'].map({'GT3':1,'LE3':0})

# %%
df
# Out:
#     school  sex  address  famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP    0        1      1.0       A     4   4.0   at_home   teacher
# 1       GP    0        1      1.0       T     1   1.0   at_home     other
# 2       GP    0        1      0.0       T     1   1.0   at_home     other
# 3       GP    0        1      1.0       T     4   2.0    health  services
# 4       GP    0        1      1.0       T     3   3.0     other     other
# ..     ...  ...      ...      ...     ...   ...   ...       ...       ...
# 644     MS    0        0      1.0       T     2   3.0  services     other
# 645     MS    0        1      0.0       T     3   1.0   teacher  services
# 646     MS    0        1      1.0       T     1   1.0     other     other
# 647     MS    1        1      0.0       T     3   1.0  services  services
# 648     MS    1        0      0.0       T     3   2.0  services     other
#
#      reason  ... Dalc  health  absences  G1    G2  G3 Feature_1 Feature_2  \
# ...

# %%
df['Pstatus'] = df['Pstatus'].map({'T':1,'A':0})

# %%
df['Mjob'] = df['Mjob'].map({'teacher':0,'health':1, 'services':2, 'at_home':3, 'other':4})
df['Fjob'] = df['Fjob'].map({'teacher':0,'health':1, 'services':2, 'at_home':3, 'other':4})

# %%
df['reason'] = df['reason'].map({'home':0,'reputation':1, 'course':2, 'other':3})

# %%
df['guardian'] = df['guardian'].map({'mother':0,'father':1, 'other':2})

# %%
df['schoolsup'] = df['schoolsup'].map({'no':0,'yes':1})
df[['paid','higher','schoolsup','famsup']]
# Out:
#     paid higher  schoolsup famsup
# 0     no    yes          1     no
# 1     no    yes          0    yes
# 2     no    yes          1     no
# 3     no    yes          0    yes
# 4     no    yes          0    yes
# ..   ...    ...        ...    ...
# 644   no    yes          0     no
# 645   no    NaN          0    yes
# 646   no    yes          0     no
# 647   no    yes          0     no
# 648   no    NaN          0     no
#
# [649 rows x 4 columns]

# %%
df['famsup'] = df['famsup'].map({'no':0,'yes':1})

# %%
df['paid'] = df['paid'].map({'no':0,'yes':1})

# %%
df['internet'] = df['internet'].map({'no':0,'yes':1})

# %%
df['activities'] = df['activities'].map({'no':0,'yes':1})

# %%
df['nursery'] = df['nursery'].map({'no':0,'yes':1})

# %%
df['higher'] = df['higher'].map({'no':0,'yes':1})

# %%
df['romantic'] = df['romantic'].map({'no':0,'yes':1})

# %%
df["school"] = df["school"].map({"GP":0,"MS":1})

# %%
df
# Out:
#      school  sex  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  \
# 0         0    0        1      1.0        0     4   4.0     3     0       2
# 1         0    0        1      1.0        1     1   1.0     3     4       2
# 2         0    0        1      0.0        1     1   1.0     3     4       3
# 3         0    0        1      1.0        1     4   2.0     1     2       0
# 4         0    0        1      1.0        1     3   3.0     4     4       0
# ..      ...  ...      ...      ...      ...   ...   ...   ...   ...     ...
# 644       1    0        0      1.0        1     2   3.0     2     4       2
# 645       1    0        1      0.0        1     3   1.0     0     2       2
# 646       1    0        1      1.0        1     1   1.0     4     4       2
# 647       1    1        1      0.0        1     3   1.0     2     2       2
# 648       1    1        0      0.0        1     3   2.0     2     4       2
#
# ...

# %%
cm=df.corr()
cm
# Out:
#               school       sex   address   famsize   Pstatus      Medu  \
# school      1.000000 -0.083050 -0.354520  0.001419  0.028120 -0.254787
# sex        -0.083050  1.000000  0.025503 -0.099494  0.064700  0.119127
# address    -0.354520  0.025503  1.000000 -0.065230 -0.094635  0.190320
# famsize     0.001419 -0.099494 -0.065230  1.000000  0.227377  0.003707
# Pstatus     0.028120  0.064700 -0.094635  0.227377  1.000000 -0.057174
# Medu       -0.254787  0.119127  0.190320  0.003707 -0.057174  1.000000
# Fedu       -0.209212  0.072940  0.144403  0.028709 -0.038705  0.645266
# Mjob        0.151608 -0.114223 -0.128512  0.069992 -0.025812 -0.536829
# Fjob        0.018211 -0.054325 -0.069587 -0.046958 -0.057947 -0.236021
# reason      0.257056 -0.028519 -0.163674  0.037018  0.065814 -0.100401
# guardian    0.033364  0.019301 -0.026165  0.016417  0.007587 -0.111274
# traveltime  0.258802  0.026798 -0.353922 -0.010840  0.030871 -0.285188
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cm)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# #### Feature_1 as we can see depends ---
# #### Linearly with failures
# #### Inversely with schoolsupport, G1,G2,G3 and more -vely with higher studies
# ### So I think it might be time spent with phone as it would detoriate grades and lead to more failures
# #### Feature_3 ---
# #### proportional with alcohol consumption, go_out and freetimes
# #### inversely proportional to grades
# ### This might indicate the number of days the student bunk classes
# #### Feature_2 ---
# #### proportional to grades
# #### inverse relation with dalc, absences and feature 3
# ### This indicates the number of surprise class tests he passed

# %% [markdown]
# # Level 2

# %%
from sklearn.impute import KNNImputer
num_cols = df.select_dtypes(include='number').columns
df[num_cols] = pd.DataFrame(KNNImputer(n_neighbors=5).fit_transform(df[num_cols]),columns=num_cols,index=df.index).round().astype(int)
df.to_csv('updated.csv', index=False)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    int64
#  1   sex         649 non-null    int64
#  2   address     649 non-null    int64
#  3   famsize     649 non-null    int64
#  4   Pstatus     649 non-null    int64
#  5   Medu        649 non-null    int64
#  6   Fedu        649 non-null    int64
#  7   Mjob        649 non-null    int64
#  8   Fjob        649 non-null    int64
#  9   reason      649 non-null    int64
#  10  guardian    649 non-null    int64
#  11  traveltime  649 non-null    int64
#  12  failures    649 non-null    int64
#  13  schoolsup   649 non-null    int64
#  14  famsup      649 non-null    int64
#  15  paid        649 non-null    int64
#  16  activities  649 non-null    int64
#  17  nursery     649 non-null    int64
#  18  higher      649 non-null    int64
# ...

# %%
cm2=df.corr()
cm2
# Out:
#               school       sex   address   famsize   Pstatus      Medu  \
# school      1.000000 -0.083050 -0.354520 -0.007001  0.028120 -0.254787
# sex        -0.083050  1.000000  0.025503 -0.089529  0.064700  0.119127
# address    -0.354520  0.025503  1.000000 -0.059344 -0.094635  0.190320
# famsize    -0.007001 -0.089529 -0.059344  1.000000  0.205778  0.012576
# Pstatus     0.028120  0.064700 -0.094635  0.205778  1.000000 -0.057174
# Medu       -0.254787  0.119127  0.190320  0.012576 -0.057174  1.000000
# Fedu       -0.220565  0.095282  0.145057  0.040504 -0.025482  0.644218
# Mjob        0.151608 -0.114223 -0.128512  0.056125 -0.025812 -0.536829
# Fjob        0.018211 -0.054325 -0.069587 -0.039714 -0.057947 -0.236021
# reason      0.257056 -0.028519 -0.163674  0.039587  0.065814 -0.100401
# guardian    0.033364  0.019301 -0.026165  0.020343  0.007587 -0.111274
# traveltime  0.257191  0.018668 -0.348904 -0.001980  0.053394 -0.278583
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(cm2)
plt.title("Correlation Matrix after filling null cells")
plt.show()

# %% [markdown]
# # Level 3

# %%
sns.barplot(x='famrel', y='G3', data=df)
plt.title('Grade vs family rel')
plt.xlabel('family relationship')
plt.ylabel('G3')
plt.show()

# %% [markdown]
# #### We can see here that student having better family relationship perform better than those who have worse

# %%
sns.barplot(x='address', y='Medu', data=df)
plt.title('education with urban/rural')
plt.xlabel('0:rural, 1:urban')
plt.ylabel('mothers education')
plt.show()

# %%
sns.barplot(x='address', y='Fedu', data=df)
plt.title('education with urban/rural')
plt.xlabel('0:rural, 1:urban')
plt.ylabel('fathers education')
plt.show()

# %% [markdown]
# #### here we can see that urban people are getting more education, so therre is a need to setup schools and educational institutes in villages

# %% [markdown]
# ### Q. Job preference/popularity for both urban and rural people

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Fjob', hue='address', data=df)
plt.title('Job Distribution by Rural/Urban Area')
plt.xlabel('Job Category')
plt.ylabel('Number of Fathers')
plt.legend(title='Location', labels=['Rural', 'Urban'])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Mjob', hue='address', data=df)
plt.title('Job Distribution by Rural/Urban Area')
plt.xlabel('Job Category')
plt.ylabel('Number of Mothers')
plt.legend(title='Location', labels=['Rural', 'Urban'])
plt.show()

# %% [markdown]
# #### From above graphs we can conclude that rural people are very less in health and teaching jobs wrt urban people
# #### Also it can be noted that the jobs like most fathers are in others category which might have been ‘manufacturing sector’ and then in the services sector. Similar trend was seen in mothers in urban region but with less strong inclination towards those two.
# #### We can also observe that health and teaching sectors are also the least popular among all of the job categories
# #### We can also observe that a lot of mothers are at home as housewife from which we can say that specially women education is needed in both urban and rural areas so that more women can get into the job market.

# %%
sns.barplot(x='G3', y='higher', data=df)
plt.title('Grades vs higher studies')
plt.xlabel('G3')
plt.ylabel('Higher studies')
plt.show()

# %% [markdown]
# #### We can see that students who earn higher grades tend to opt for higher studies more
# #### Also there is a tendency among all the top-class students (marks>=15) to pursue higher studies

# %% [markdown]
# # Level 4

# %%
rcm = cm[['romantic']].drop('romantic')
rcm
# Out:
#             romantic
# school      0.072241
# sex        -0.110144
# address    -0.030939
# famsize     0.015105
# Pstatus    -0.053828
# Medu       -0.030992
# Fedu       -0.057864
# Mjob        0.059196
# Fjob        0.003189
# reason      0.039456
# guardian    0.066583
# traveltime  0.007572
# failures    0.069901
# schoolsup  -0.094310
# famsup     -0.023398
# paid       -0.018309
# activities  0.057517
# nursery    -0.022984
# higher     -0.105584
# internet    0.034832
# famrel     -0.044920
# freetime    0.016873
# goout      -0.000520
# Dalc        0.062042
# health     -0.018025
# absences    0.093977
# G1         -0.074973
# G2         -0.107950
# G3         -0.090583
# Feature_1   0.180214
# Feature_2   0.051233
# Feature_3  -0.005915

# %%
plt.figure(figsize=(3, 6))
sns.heatmap(rcm, cmap='coolwarm')
plt.title("Correlation Plot of romantic")
plt.show()

# %% [markdown]
# #### as per the above graph we can see that for a student being romantic depends directly with Feature_1 which I found to be the hours spent on mobile phones. With this I can say that he must be chatting or talking with his partner in mobile phone leading to increased time with phone. We also can see that it slightly depends with absences from which we can say that he must be leaving school to meet his partner. Also it is inversely related with grades, higher studies and school support. This tells us that students struggle a bit with their studies when in relationship. Also the support from the school is not being received for which proper counselling to manage both lacks. Also when romantic tends to 1 the sex tends to 0 as per graph which says that girls are more in it.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X=df[['higher', 'schoolsup', 'goout', 'absences', 'Feature_1', 'G1', 'G2', 'G3', 'Dalc', 'guardian', 'failures', 'sex']]
y=df[['romantic']]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5)
model_lr=LogisticRegression(max_iter=1000)
model_lr.fit(X_train, y_train)
y_pred=model_lr.predict(X_test)
model_lr.score(X_test, y_test)
# Out:
# C:\Users\Hp\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.64

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
model_svm = make_pipeline(StandardScaler(), SVC())
model_svm.fit(X, y)
pipeline.score(X_test, y_test)
# Out:
# C:\Users\Hp\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.6338461538461538

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt=DecisionTreeClassifier()
model_dt.fit(X_train, y_train)
model_dt.score(X_test, y_test)
# Out:
# 0.5076923076923077

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier()
model_rf.fit(X_train, y_train)
model_rf.score(X_test, y_test)
# Out:
# C:\Users\Hp\AppData\Roaming\Python\Python313\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# 0.5753846153846154

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import accuracy_score, classification_report
majority_class=0
X_train_majority_only = X_train[y_train==majority_class]
from sklearn.ensemble import IsolationForest
iso=IsolationForest(contamination=0.1)
iso.fit(X_train_majority_only)
y_pred=iso.predict(X_test)
y_pred_binary = [1 if x == -1 else 0 for x in y_pred]
iso=IsolationForest(contamination=0.1)
iso.fit(X_train_majority_only)
y_pred=iso.predict(X_test)
y_pred_binary = [1 if x == -1 else 0 for x in y_pred]
accuracy_score(y_test, y_pred_binary)
# Out:
# 0.6215384615384615

# %% [markdown]
# #### From the above models we can say that nearly every model is giving similar score. But Isolation forest is giving consistent score above 60 everytime as it does random splitting of data. Also I noticed that Logistic regression gives slightly better score as compared to others.

# %% [markdown]
# # Level 5

# %%
from sklearn.inspection import DecisionBoundaryDisplay
df_encoded = df.copy()
label_encoders = {}
target='romantic'
for col in df_encoded.select_dtypes(include='object').columns: 
    le=LabelEncoder()
    df_encoded[col]=le.fit_transform(df_encoded[col])
    label_encoders[col] = le
features=[col for col in df_encoded.columns if col != target]
X=df_encoded[features]
y=df_encoded[target]
#For 2D plotting
features_2d = ['higher', 'absences']
X2D = df_encoded[features_2d]

# %%
model_lr = LogisticRegression()
model_lr.fit(X2D, y)
DecisionBoundaryDisplay.from_estimator(model_lr, X2D, response_method="predict", cmap=plt.cm.coolwarm)
plt.scatter(X2D[features_2d[0]], X2D[features_2d[1]], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.xlabel(features_2d[0])
plt.ylabel(features_2d[1])
plt.title("Logistic regression Decision Boundary")
plt.show()

# %%
model_svm = SVC()
model_svm.fit(X2D, y)
DecisionBoundaryDisplay.from_estimator(model_svm, X2D, response_method="predict", cmap=plt.cm.coolwarm)
plt.scatter(X2D[features_2d[0]], X2D[features_2d[1]], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.xlabel(features_2d[0])
plt.ylabel(features_2d[1])
plt.title("SVM Decision Boundary")
plt.show()

# %%
model_dt = DecisionTreeClassifier()
model_dt.fit(X2D, y)
DecisionBoundaryDisplay.from_estimator(model_dt, X2D, response_method="predict", cmap=plt.cm.coolwarm)
plt.scatter(X2D[features_2d[0]], X2D[features_2d[1]], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.xlabel(features_2d[0])
plt.ylabel(features_2d[1])
plt.title("Decision tree Decision Boundary")
plt.show()

# %%
model_rf = RandomForestClassifier()
model_rf.fit(X2D, y)
DecisionBoundaryDisplay.from_estimator(model_rf, X2D, response_method="predict", cmap=plt.cm.coolwarm)
plt.scatter(X2D[features_2d[0]], X2D[features_2d[1]], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.xlabel(features_2d[0])
plt.ylabel(features_2d[1])
plt.title("Random forest Decision Boundary")
plt.show()

# %%
model_if = IsolationForest()
model_if.fit(X2D, y)
DecisionBoundaryDisplay.from_estimator(model_if, X2D, response_method="predict", cmap=plt.cm.coolwarm)
plt.scatter(X2D[features_2d[0]], X2D[features_2d[1]], c=y, edgecolor="k", cmap=plt.cm.coolwarm)
plt.xlabel(features_2d[0])
plt.ylabel(features_2d[1])
plt.title("Isolation forest Decision Boundary")
plt.show()

# %% [markdown]
# # Bonus Level

# %%
# Plot-1 : Likely Random forest as it has amooth edges like rectangular grids
# Plot-2 : Likely Decision tree as it has very rough edges
# Plot-3 : Likely SVM as it gives non-linear smooth curved boundary
# Plot-4 : Likely SVM as it gives non-linear smooth curved boundary
# Plot-5 : Likely Logistic as it has linear boundaries in the left end and also it might have some other methods used with logistic regression
